# %% [markdown]
# # Download Data From SEt50, GOLD, OIL

# %%
from statsmodels.regression.rolling import RollingOLS
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd
import numpy as np
import datetime as dt
import yfinance as yf
import pandas_ta
import warnings
warnings.filterwarnings('ignore')

#set date
end_date = '2024-05-10'
start_date = pd.to_datetime(end_date)-pd.DateOffset(30*5)

SET50 = yf.download("^SET.BK", start = start_date, end = end_date)
GOLD = yf.download("GC=F", start = start_date, end = end_date)
OIL = yf.download("CL=F", start = start_date, end = end_date)
#show graph
def plot_show(data,set_color,set_title):
    # Plotting
    plt.figure(figsize=(14, 4))
    plt.plot(data['Close'], label='Price', color=set_color)
    plt.title(set_title)
    plt.xlabel('Date')
    plt.ylabel('Price (USD)')
    plt.legend()
    plt.grid(True)
    plt.show()

plot_show(SET50, 'blue', 'SET50 Price')
plot_show(GOLD, 'gold', 'GOLD Price')
plot_show(OIL, 'black', 'OIL Price')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# # Preprocess Data (use only close price)

# %%
import pandas as pd
# Preprocess data SET50
dataset = SET50.copy()
dataset = dataset.reset_index()
dataset['Date'] = pd.to_datetime(dataset['Date'])
dataset.set_index('Date', inplace=True)
SET50 = dataset['Close'].to_frame()

# Preprocess data GOLD
dataset_gold = GOLD.copy()
dataset_gold = dataset_gold.reset_index()
dataset_gold['Date'] = pd.to_datetime(dataset_gold['Date'])
dataset_gold.set_index('Date', inplace=True)
GOLD = dataset_gold['Close'].to_frame()

# Preprocess data OIL
dataset_oil = OIL.copy()
dataset_oil = dataset_oil.reset_index()
dataset_oil['Date'] = pd.to_datetime(dataset_oil['Date'])
dataset_oil.set_index('Date', inplace=True)
OIL = dataset_oil['Close'].to_frame()

# %% [markdown]
# # SET50 ARIMA

# %%
from pmdarima.arima import auto_arima
def arima_model(data):
    model = auto_arima(data['Close'], seasonal=False, trace=True)
    print(model.summary())
arima_model(SET50)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=710.291, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=712.202, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=712.182, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=708.293, Time=0.00 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=713.911, Time=0.03 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.221 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   97
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                -353.147
# Date:                Sun, 12 May 2024   AIC                            708.293
# Time:                        16:06:56   BIC                            710.857
# Sample:                             0   HQIC                           709.330
#                                  - 97
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        91.7753     10.637      8.628      0.000      70.927     112.623
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.09   Jarque-Bera (JB):                 5.00
# Prob(Q):                              0.76   Prob(JB):                         0.08
# Heteroskedasticity (H):               1.21   Skew:                            -0.10
# Prob(H) (two-sided):                  0.59   Kurtosis:                         4.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
from statsmodels.tsa.arima.model import ARIMA
import numpy as np

# Define the ARIMA model
def arima_forecast(history):
    # Fit the model
    model = ARIMA(history, order=(1,1,1))
    model_fit = model.fit()
    
    # Make the prediction
    output = model_fit.forecast()
    yhat = output[0]
    return yhat

# %%
# Split data into train and test sets
X = SET50.values
size = int(len(X) * 0.8)
train, test = X[0:size], X[size:len(X)]

# Walk-forward validation
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    # Generate a prediction
    yhat = arima_forecast(history)
    predictions.append(yhat)
    # Add the predicted value to the training set
    obs = test[t]
    history.append(obs)
plt.figure(figsize=(12, 3), dpi=100)
plt.plot(SET50.iloc[size:,:].index, test, label='Real')
plt.plot(SET50.iloc[size:,:].index, predictions, color='red', label='Predicted')
plt.title('ARIMA Predictions vs Actual Values')
plt.xlabel('Date')
plt.ylabel('SET50 Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# Convert test and predictions to numpy arrays for calculation
test = np.array(test)
predictions = np.array(predictions)

# Calculate MAE
mae = mean_absolute_error(test, predictions)
print(f"Mean Absolute Error (MAE): {mae}")

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(test, predictions))
print(f"Root Mean Squared Error (RMSE): {rmse}")

# Calculate MAPE
mape = np.mean(np.abs((test - predictions) / test)) * 100
print(f"Mean Absolute Percentage Error (MAPE): {mape}%")
# Out:
# Mean Absolute Error (MAE): 9.0773994274473
# Root Mean Squared Error (RMSE): 12.777023010510954
# Mean Absolute Percentage Error (MAPE): 1.2951523700177723%

# %% [markdown]
# # GOLD ARIMA

# %%
arima_model(GOLD)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=874.969, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=876.789, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=876.819, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=877.002, Time=0.00 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=878.720, Time=0.05 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 0.232 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  103
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                -435.484
# Date:                Sun, 12 May 2024   AIC                            874.969
# Time:                        16:06:57   BIC                            880.219
# Sample:                             0   HQIC                           877.095
#                                 - 103
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      3.4735      1.811      1.918      0.055      -0.076       7.023
# sigma2       299.1761     29.405     10.174      0.000     241.544     356.808
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.19   Jarque-Bera (JB):                35.57
# Prob(Q):                              0.67   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.99   Skew:                            -0.69
# Prob(H) (two-sided):                  0.05   Kurtosis:                         5.54
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Split data into train and test sets
X = GOLD.values
size = int(len(X) * 0.8)
train, test = X[0:size], X[size:len(X)]

# Walk-forward validation
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    # Generate a prediction
    yhat = arima_forecast(history)
    predictions.append(yhat)
    # Add the predicted value to the training set
    obs = test[t]
    history.append(obs)
plt.figure(figsize=(12, 3), dpi=100)
plt.plot(GOLD.iloc[size:,:].index, test, label='Real')
plt.plot(GOLD.iloc[size:,:].index, predictions, color='red', label='Predicted')
plt.title('ARIMA Predictions vs Actual Values')
plt.xlabel('Date')
plt.ylabel('SET50 Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# Convert test and predictions to numpy arrays for calculation
test = np.array(test)
predictions = np.array(predictions)

# Calculate MAE
mae = mean_absolute_error(test, predictions)
print(f"Mean Absolute Error (MAE): {mae}")

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(test, predictions))
print(f"Root Mean Squared Error (RMSE): {rmse}")

# Calculate MAPE
mape = np.mean(np.abs((test - predictions) / test)) * 100
print(f"Mean Absolute Percentage Error (MAPE): {mape}%")
# Out:
# Mean Absolute Error (MAE): 15.200033676488667
# Root Mean Squared Error (RMSE): 23.379070069281543
# Mean Absolute Percentage Error (MAPE): 1.5599232800625777%

# %% [markdown]
# # OIL ARIMA

# %%
arima_model(OIL)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=332.415, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=328.644, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=329.822, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=329.962, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=327.428, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=329.123, Time=0.04 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.144 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  103
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                -162.714
# Date:                Sun, 12 May 2024   AIC                            327.428
# Time:                        16:06:58   BIC                            330.053
# Sample:                             0   HQIC                           328.491
#                                 - 103
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         1.4227      0.214      6.659      0.000       1.004       1.842
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.85   Jarque-Bera (JB):                 2.19
# Prob(Q):                              0.36   Prob(JB):                         0.33
# Heteroskedasticity (H):               0.52   Skew:                            -0.35
# Prob(H) (two-sided):                  0.06   Kurtosis:                         2.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Split data into train and test sets
X = OIL.values
size = int(len(X) * 0.8)
train, test = X[0:size], X[size:len(X)]

# Walk-forward validation
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    # Generate a prediction
    yhat = arima_forecast(history)
    predictions.append(yhat)
    # Add the predicted value to the training set
    obs = test[t]
    history.append(obs)
plt.figure(figsize=(12, 3), dpi=100)
plt.plot(OIL.iloc[size:,:].index, test, label='Real')
plt.plot(OIL.iloc[size:,:].index, predictions, color='red', label='Predicted')
plt.title('ARIMA Predictions vs Actual Values')
plt.xlabel('Date')
plt.ylabel('SET50 Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# Convert test and predictions to numpy arrays for calculation
test = np.array(test)
predictions = np.array(predictions)

# Calculate MAE
mae = mean_absolute_error(test, predictions)
print(f"Mean Absolute Error (MAE): {mae}")

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(test, predictions))
print(f"Root Mean Squared Error (RMSE): {rmse}")

# Calculate MAPE
mape = np.mean(np.abs((test - predictions) / test)) * 100
print(f"Mean Absolute Percentage Error (MAPE): {mape}%")
# Out:
# Mean Absolute Error (MAE): 0.7257727462027652
# Root Mean Squared Error (RMSE): 1.0249710928358264
# Mean Absolute Percentage Error (MAPE): 3.512646335852098%

# %% [markdown]
# # Prepare LSTM

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # SET50 LSTM

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt

def prepare_data(data, n_features):
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data)

    X = []
    y = []
    dates = []
    for i in range(60, len(scaled_data)):  # Starting from day 60
        X.append(scaled_data[i-60:i, 0])
        y.append(scaled_data[i, 0])
        dates.append(data.index[i])
    X, y, dates = np.array(X), np.array(y), np.array(dates)

    if X.shape[0] == 0:
        return None, None, None, None, None, None

    X = np.reshape(X, (X.shape[0], X.shape[1], n_features))
    
    # Modify where to split for train and test to ensure alignment with ARIMA start
    split_point = len(X) - int(0.2 * len(data))  # Make test set size 20% of the entire dataset, not the reduced (data-60 days)
    X_train, X_test = X[:split_point], X[split_point:]
    y_train, y_test = y[:split_point], y[split_point:]
    train_dates, test_dates = dates[:split_point], dates[split_point:]

    return X_train, y_train, X_test, y_test, scaler, test_dates

# Rest of the code remains the same.


def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=input_shape))
    model.add(LSTM(units=50, return_sequences=False))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

def plot_predictions(dates, real, predicted):
    plt.figure(figsize=(12, 3))
    plt.plot(dates, real, color='blue', label='Real Price')
    plt.plot(dates, predicted, color='red', label='Predicted Price')
    plt.title('Price Prediction Comparison')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

data = SET50[['Close']]
X_train, y_train, X_test, y_test, scaler, test_dates = prepare_data(data, n_features=1)

if X_train is None:
    print("Not enough data to create any training samples. Check your data source or reduce the timestep window.")
else:
    model = build_lstm_model(input_shape=(X_train.shape[1], 1))
    model.fit(X_train, y_train, epochs=100, batch_size=32)

    test_pred = model.predict(X_test)
    test_pred = scaler.inverse_transform(test_pred)
    real_test = scaler.inverse_transform(y_test.reshape(-1,1))

    plot_predictions(test_dates, real_test, test_pred)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.2285
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1656
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1107
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0626
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0244
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0042
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0138
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0347
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0346
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0224
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0109
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0048
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0036
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0053
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0080
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0104
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0119
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0123
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0117
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0104
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0087
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0069
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0053
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0042
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0037
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0039
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0044
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0051
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0058
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0060
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0059
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0054
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0048
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0043
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0039
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0037
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0038
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0039
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0041
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0043
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0044
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0044
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0044
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0042
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0040
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0039
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0038
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0037
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0037
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0038
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0039
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0039
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0039
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0039
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0039
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0038
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0038
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0037
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0037
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0038
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0038
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0038
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0038
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0038
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0037
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0037
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0037
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0037
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0037
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0037
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0037
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0037
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0037
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0037
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0037
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0037
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0037
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0037
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0037
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0037
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0037
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0037
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0036
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0036
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0036
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0036
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Assuming test_pred and real_test are already defined from your previous predictions
mae = mean_absolute_error(real_test, test_pred)
rmse = np.sqrt(mean_squared_error(real_test, test_pred))
mape = calculate_mape(real_test, test_pred)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.12f}%")
# Out:
# Mean Absolute Error (MAE): 15.121909693667764
# Root Mean Squared Error (RMSE): 19.08784754188327
# Mean Absolute Percentage Error (MAPE): 1.107599890802%

# %% [markdown]
# # GOLD LSTM

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt

def prepare_data(data, n_features):
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data)

    X = []
    y = []
    dates = []
    for i in range(60, len(scaled_data)):  # Starting from day 60
        X.append(scaled_data[i-60:i, 0])
        y.append(scaled_data[i, 0])
        dates.append(data.index[i])
    X, y, dates = np.array(X), np.array(y), np.array(dates)

    if X.shape[0] == 0:
        return None, None, None, None, None, None

    X = np.reshape(X, (X.shape[0], X.shape[1], n_features))
    
    # Modify where to split for train and test to ensure alignment with ARIMA start
    split_point = len(X) - int(0.2 * len(data))  # Make test set size 20% of the entire dataset, not the reduced (data-60 days)
    X_train, X_test = X[:split_point], X[split_point:]
    y_train, y_test = y[:split_point], y[split_point:]
    train_dates, test_dates = dates[:split_point], dates[split_point:]

    return X_train, y_train, X_test, y_test, scaler, test_dates

# Rest of the code remains the same.


def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=input_shape))
    model.add(LSTM(units=50, return_sequences=False))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

def plot_predictions(dates, real, predicted):
    plt.figure(figsize=(12, 3))
    plt.plot(dates, real, color='blue', label='Real Price')
    plt.plot(dates, predicted, color='red', label='Predicted Price')
    plt.title('Price Prediction Comparison')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

data = GOLD[['Close']]
X_train, y_train, X_test, y_test, scaler, test_dates = prepare_data(data, n_features=1)

if X_train is None:
    print("Not enough data to create any training samples. Check your data source or reduce the timestep window.")
else:
    model = build_lstm_model(input_shape=(X_train.shape[1], 1))
    model.fit(X_train, y_train, epochs=100, batch_size=32)

    test_pred = model.predict(X_test)
    test_pred = scaler.inverse_transform(test_pred)
    real_test = scaler.inverse_transform(y_test.reshape(-1,1))

    plot_predictions(test_dates, real_test, test_pred)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.3112
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2536
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1998
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1495
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1031
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0620
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0290
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0094
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0102
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0305
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0461
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0445
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0327
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0201
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0115
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0077
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0077
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0099
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0127
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0153
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0170
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0177
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0174
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0162
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0145
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0124
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0105
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0089
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0079
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0075
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0079
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0086
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0094
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0100
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0102
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0099
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0093
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0086
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0079
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0075
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0073
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0073
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0075
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0077
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0079
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0080
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0079
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0078
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0075
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0073
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0071
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0069
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0069
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0069
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0069
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0070
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0070
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0069
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0068
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0067
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0066
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0065
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0064
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0064
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0064
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0064
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0064
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0064
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0063
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0062
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0062
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0061
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0061
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0060
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0060
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0060
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0060
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0059
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0059
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0058
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0058
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0058
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0057
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0057
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0057
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0057
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0056
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0056
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0056
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0055
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0055
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0055
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0055
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0054
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0054
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0054
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0054
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0053
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0053
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0053
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Assuming test_pred and real_test are already defined from your previous predictions
mae = mean_absolute_error(real_test, test_pred)
rmse = np.sqrt(mean_squared_error(real_test, test_pred))
mape = calculate_mape(real_test, test_pred)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.12f}%")
# Out:
# Mean Absolute Error (MAE): 114.46390380859376
# Root Mean Squared Error (RMSE): 130.57839716456954
# Mean Absolute Percentage Error (MAPE): 4.932353323392%

# %% [markdown]
# # OIL LSTM

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt

def prepare_data(data, n_features):
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data)

    X = []
    y = []
    dates = []
    for i in range(60, len(scaled_data)):  # Starting from day 60
        X.append(scaled_data[i-60:i, 0])
        y.append(scaled_data[i, 0])
        dates.append(data.index[i])
    X, y, dates = np.array(X), np.array(y), np.array(dates)

    if X.shape[0] == 0:
        return None, None, None, None, None, None

    X = np.reshape(X, (X.shape[0], X.shape[1], n_features))
    
    # Modify where to split for train and test to ensure alignment with ARIMA start
    split_point = len(X) - int(0.2 * len(data))  # Make test set size 20% of the entire dataset, not the reduced (data-60 days)
    X_train, X_test = X[:split_point], X[split_point:]
    y_train, y_test = y[:split_point], y[split_point:]
    train_dates, test_dates = dates[:split_point], dates[split_point:]

    return X_train, y_train, X_test, y_test, scaler, test_dates

# Rest of the code remains the same.


def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=input_shape))
    model.add(LSTM(units=50, return_sequences=False))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

def plot_predictions(dates, real, predicted):
    plt.figure(figsize=(12, 3))
    plt.plot(dates, real, color='blue', label='Real Price')
    plt.plot(dates, predicted, color='red', label='Predicted Price')
    plt.title('Price Prediction Comparison')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

data = OIL[['Close']]
X_train, y_train, X_test, y_test, scaler, test_dates = prepare_data(data, n_features=1)

if X_train is None:
    print("Not enough data to create any training samples. Check your data source or reduce the timestep window.")
else:
    model = build_lstm_model(input_shape=(X_train.shape[1], 1))
    model.fit(X_train, y_train, epochs=100, batch_size=32)

    test_pred = model.predict(X_test)
    test_pred = scaler.inverse_transform(test_pred)
    real_test = scaler.inverse_transform(y_test.reshape(-1,1))

    plot_predictions(test_dates, real_test, test_pred)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.6450
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.5476
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.4565
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.3683
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2815
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1964
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1162
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0491
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0104
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0213
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0691
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0897
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0752
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0478
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0245
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0115
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0080
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0105
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0157
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0211
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0251
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0272
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0273
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0256
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0226
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0188
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0150
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0116
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0093
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0082
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0085
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0097
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0113
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0127
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0134
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0132
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0122
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0109
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0096
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0087
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0082
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0082
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0085
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0090
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0094
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0096
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0097
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0095
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0092
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0089
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0085
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0082
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0081
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0081
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0082
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0083
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0084
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0085
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0084
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0083
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0082
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0080
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0079
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0079
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0079
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0079
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0080
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0080
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0080
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0080
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0079
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0078
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0078
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0077
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0077
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0077
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0077
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0077
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0077
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0077
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0077
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0076
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0076
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0076
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0076
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0075
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0075
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0075
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0075
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0075
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0075
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0075
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0074
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0074
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0074
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0074
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0074
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0074
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0073
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0073
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Assuming test_pred and real_test are already defined from your previous predictions
mae = mean_absolute_error(real_test, test_pred)
rmse = np.sqrt(mean_squared_error(real_test, test_pred))
mape = calculate_mape(real_test, test_pred)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.12f}%")
# Out:
# Mean Absolute Error (MAE): 4.2493034362792965
# Root Mean Squared Error (RMSE): 4.676771247045281
# Mean Absolute Percentage Error (MAPE): 5.265671425884%

# %% [markdown]
# # SET50 Prophet

# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Assuming SET50 is your DataFrame and it has a 'Date' and 'Close' columns

# Prepare data for Prophet
df = pd.DataFrame()
df['ds'] = SET50.index  # Ensure this is datetime
df['y'] = SET50['Close'].values
# df
# len(df)
# Split data into train and test sets
size = int(len(df) * 0.8)
train = df.iloc[:size]
test = df.iloc[size:]

# Fit the Prophet model
model = Prophet(daily_seasonality=False, weekly_seasonality=False, yearly_seasonality=False)
model.fit(train)

# Make a future dataframe for predictions
future = model.make_future_dataframe(periods=len(test), freq='D', include_history=False)

# Predict
forecast = model.predict(future)
len(forecast)
# Plot
plt.figure(figsize=(12, 3))
plt.plot(df['ds'][size:], df['y'][size:], label='Real')
plt.plot(forecast['ds'], forecast['yhat'], color='red', label='Predicted')

plt.title('Prophet Predictions vs Actual Values')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# Date formatting on X-axis
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=4))

plt.grid(True)
plt.show()
# Out:
# 17:02:27 - cmdstanpy - INFO - Chain [1] start processing
# 17:02:27 - cmdstanpy - INFO - Chain [1] done processing

# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Assuming SET50 is your DataFrame and it has a 'Date' and 'Close' columns

# Prepare data for Prophet
df = pd.DataFrame()
df['ds'] = GOLD.index  # Ensure this is datetime
df['y'] = GOLD['Close'].values
# df
# len(df)
# Split data into train and test sets
size = int(len(df) * 0.8)
train = df.iloc[:size]
test = df.iloc[size:]

# Fit the Prophet model
model = Prophet(daily_seasonality=False, weekly_seasonality=False, yearly_seasonality=False)
model.fit(train)

# Make a future dataframe for predictions
future = model.make_future_dataframe(periods=len(test), freq='D', include_history=False)

# Predict
forecast = model.predict(future)
len(forecast)
# Plot
plt.figure(figsize=(12, 3))
plt.plot(df['ds'][size:], df['y'][size:], label='Real')
plt.plot(forecast['ds'], forecast['yhat'], color='red', label='Predicted')

plt.title('Prophet Predictions vs Actual Values')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# Date formatting on X-axis
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=4))

plt.grid(True)
plt.show()
# Out:
# 17:03:18 - cmdstanpy - INFO - Chain [1] start processing
# 17:03:18 - cmdstanpy - INFO - Chain [1] done processing

# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Assuming SET50 is your DataFrame and it has a 'Date' and 'Close' columns

# Prepare data for Prophet
df = pd.DataFrame()
df['ds'] = OIL.index  # Ensure this is datetime
df['y'] = OIL['Close'].values
# df
# len(df)
# Split data into train and test sets
size = int(len(df) * 0.8)
train = df.iloc[:size]
test = df.iloc[size:]

# Fit the Prophet model
model = Prophet(daily_seasonality=False, weekly_seasonality=False, yearly_seasonality=False)
model.fit(train)

# Make a future dataframe for predictions
future = model.make_future_dataframe(periods=len(test), freq='D', include_history=False)

# Predict
forecast = model.predict(future)
len(forecast)
# Plot
plt.figure(figsize=(12, 3))
plt.plot(df['ds'][size:], df['y'][size:], label='Real')
plt.plot(forecast['ds'], forecast['yhat'], color='red', label='Predicted')

plt.title('Prophet Predictions vs Actual Values')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# Date formatting on X-axis
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=4))

plt.grid(True)
plt.show()
# Out:
# 17:03:42 - cmdstanpy - INFO - Chain [1] start processing
# 17:03:43 - cmdstanpy - INFO - Chain [1] done processing
